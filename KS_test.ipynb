# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Generating Gausian rv X
x = stats.norm.rvs(size=10000)
sns.set_style('whitegrid')
sns.kdeplot(np.array(x))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
stats.kstest(x,'norm')
# Out:
# KstestResult(statistic=0.009129243249267449, pvalue=0.3729074131497482)

# %%
y = np.random.uniform(0,1,1000)
sns.kdeplot(np.array(y))
plt.show()

# %%
stats.kstest(y,'norm')
# Out:
# KstestResult(statistic=0.5000347173850991, pvalue=9.834723353243755e-232)
